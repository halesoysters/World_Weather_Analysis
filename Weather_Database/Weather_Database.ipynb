# %% [markdown]
# ### Generate a set of 2,000 random latitudes and longitudes, retrieve the nearest city, and perform an API call with the OpenWeatherMap. In addition to the city weather data you gathered in this module, use your API skills to retrieve the current weather description for each city. Then, create a new DataFrame containing the updated weather data.

# %%
#import dependencies
import pandas as pd
import requests
import numpy as np
from config import weather_api_key
from citipy import citipy
import time
from datetime import datetime
import gmaps
from config import g_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# Create an empty list to hold the weather data.
city_data = []

# Create counters.
record_count = 1
set_count = 1

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities 

    try: 
        #parse the JSON and retireve data
        city_weather = requests.get(city_url).json()
        # If an error is experienced, skip the city.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        #convert date to ISO standard
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        #append city information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Conditions": city_weather_description
                         })
    except(IndexError, NameError, KeyError):
        print("City not found. Skipping...")
        pass
# Out:
# Processing Record 58 of Set 1 | smithers
# Processing Record 59 of Set 1 | nouadhibou
# Processing Record 60 of Set 1 | airai
# Processing Record 61 of Set 1 | ponta delgada
# Processing Record 62 of Set 1 | souillac
# Processing Record 63 of Set 1 | punta arenas
# Processing Record 64 of Set 1 | port alfred
# Processing Record 65 of Set 1 | puerto escondido
# Processing Record 66 of Set 1 | olafsvik
# Processing Record 67 of Set 1 | torbay
# Processing Record 68 of Set 1 | castro
# Processing Record 69 of Set 1 | victoria
# Processing Record 70 of Set 1 | saint-philippe
# Processing Record 71 of Set 1 | alice springs
# Processing Record 72 of Set 1 | ponta do sol
# Processing Record 73 of Set 1 | albany
# Processing Record 74 of Set 1 | salamiyah
# Processing Record 75 of Set 1 | vaini
# Processing Record 76 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 77 of Set 1 | richards bay
# Processing Record 78 of Set 1 | busselton
# Processing Record 79 of Set 1 | bathsheba
# Processing Record 80 of Set 1 | mataura
# Processing Record 81 of Set 1 | ushuaia
# Processing Record 82 of Set 1 | vila franca do campo
# Processing Record 83 of Set 1 | mehamn
# Processing Record 84 of Set 1 | barrow
# Processing Record 85 of Set 1 | bairiki
# Processing Record 86 of Set 1 | pontevel
# Processing Record 87 of Set 1 | portland
# Processing Record 88 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 89 of Set 1 | nikolskoye
# Processing Record 90 of Set 1 | kapaa
# Processing Record 91 of Set 1 | jacqueville
# Processing Record 92 of Set 1 | talnakh
# Processing Record 93 of Set 1 | georgetown
# Processing Record 94 of Set 1 | kosh-agach
# Processing Record 95 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 96 of Set 1 | upernavik
# Processing Record 97 of Set 1 | truro
# Processing Record 98 of Set 1 | kununurra
# Processing Record 99 of Set 1 | clyde river
# Processing Record 100 of Set 1 | atuona
# Processing Record 101 of Set 1 | raudeberg
# Processing Record 102 of Set 1 | avarua
# Processing Record 103 of Set 1 | hermanus
# Processing Record 104 of Set 1 | bluff
# Processing Record 105 of Set 1 | port elizabeth
# Processing Record 106 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 107 of Set 1 | puerto ayora
# Processing Record 1 of Set 2 | tual
# Processing Record 2 of Set 2 | vardo
# Processing Record 3 of Set 2 | san juan
# Processing Record 4 of Set 2 | hasaki
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 2 | provideniya
# Processing Record 7 of Set 2 | peniche
# Processing Record 8 of Set 2 | bonthe
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | aswan
# Processing Record 11 of Set 2 | la ronge
# Processing Record 12 of Set 2 | henties bay
# Processing Record 13 of Set 2 | rikitea
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | klaksvik
# Processing Record 16 of Set 2 | bowen
# Processing Record 17 of Set 2 | kokkola
# Processing Record 18 of Set 2 | saint george
# Processing Record 19 of Set 2 | carnarvon
# Processing Record 20 of Set 2 | vila velha
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | upala
# Processing Record 23 of Set 2 | wanning
# Processing Record 24 of Set 2 | puerto cortes
# City not found. Skipping...
# Processing Record 25 of Set 2 | atar
# Processing Record 26 of Set 2 | harper
# Processing Record 27 of Set 2 | lae
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | grenada
# Processing Record 30 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 2 | tiksi
# Processing Record 32 of Set 2 | rorvik
# Processing Record 33 of Set 2 | mayor pablo lagerenza
# Processing Record 34 of Set 2 | mar del plata
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | nikolayevka
# Processing Record 37 of Set 2 | kota kinabalu
# Processing Record 38 of Set 2 | narasannapeta
# Processing Record 39 of Set 2 | esperance
# Processing Record 40 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 2 | salym
# Processing Record 42 of Set 2 | kavieng
# Processing Record 43 of Set 2 | nuuk
# Processing Record 44 of Set 2 | faanui
# Processing Record 45 of Set 2 | luanda
# Processing Record 46 of Set 2 | tasiilaq
# Processing Record 47 of Set 2 | caravelas
# Processing Record 48 of Set 2 | hamilton
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | parrita
# Processing Record 1 of Set 3 | poya
# Processing Record 2 of Set 3 | dikson
# Processing Record 3 of Set 3 | guerrero negro
# Processing Record 4 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 3 | qeshm
# Processing Record 6 of Set 3 | longyearbyen
# Processing Record 7 of Set 3 | taoudenni
# Processing Record 8 of Set 3 | saskylakh
# Processing Record 9 of Set 3 | chuy
# Processing Record 10 of Set 3 | yenagoa
# Processing Record 11 of Set 3 | jhanjharpur
# Processing Record 12 of Set 3 | geraldton
# Processing Record 13 of Set 3 | marsa matruh
# Processing Record 14 of Set 3 | pahrump
# Processing Record 15 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 3 | ampanihy
# Processing Record 17 of Set 3 | matiri
# Processing Record 18 of Set 3 | chokurdakh
# Processing Record 19 of Set 3 | praya
# Processing Record 20 of Set 3 | chirongui
# Processing Record 21 of Set 3 | nanortalik
# Processing Record 22 of Set 3 | rocha
# Processing Record 23 of Set 3 | dakoro
# Processing Record 24 of Set 3 | cacalchen
# Processing Record 25 of Set 3 | kvarkeno
# Processing Record 26 of Set 3 | ixtapa
# Processing Record 27 of Set 3 | hilo
# Processing Record 28 of Set 3 | ridgetown
# Processing Record 29 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 3 | ambon
# Processing Record 31 of Set 3 | shinyanga
# Processing Record 32 of Set 3 | alta floresta
# Processing Record 33 of Set 3 | geilo
# Processing Record 34 of Set 3 | saint-louis
# Processing Record 35 of Set 3 | cascais
# Processing Record 36 of Set 3 | takab
# Processing Record 37 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 3 | severo-kurilsk
# Processing Record 39 of Set 3 | narsaq
# Processing Record 40 of Set 3 | gigmoto
# Processing Record 41 of Set 3 | kirov
# Processing Record 42 of Set 3 | thompson
# Processing Record 43 of Set 3 | coihaique
# Processing Record 44 of Set 3 | cairo
# Processing Record 45 of Set 3 | sorland
# Processing Record 46 of Set 3 | san cristobal
# Processing Record 47 of Set 3 | saint-joseph
# Processing Record 48 of Set 3 | bodden town
# Processing Record 49 of Set 3 | codrington
# Processing Record 50 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 1 of Set 4 | aurora
# Processing Record 2 of Set 4 | verkhoyansk
# Processing Record 3 of Set 4 | ardakan
# Processing Record 4 of Set 4 | sobolevo
# Processing Record 5 of Set 4 | tuatapere
# Processing Record 6 of Set 4 | consett
# Processing Record 7 of Set 4 | lata
# Processing Record 8 of Set 4 | nanfeng
# Processing Record 9 of Set 4 | marquard
# Processing Record 10 of Set 4 | mayo
# Processing Record 11 of Set 4 | great falls
# Processing Record 12 of Set 4 | singapore
# Processing Record 13 of Set 4 | kangaatsiaq
# Processing Record 14 of Set 4 | askino
# Processing Record 15 of Set 4 | cherskiy
# Processing Record 16 of Set 4 | arraial do cabo
# Processing Record 17 of Set 4 | port lincoln
# Processing Record 18 of Set 4 | tsiroanomandidy
# Processing Record 19 of Set 4 | nyurba
# Processing Record 20 of Set 4 | iskateley
# Processing Record 21 of Set 4 | columbus
# Processing Record 22 of Set 4 | qurayyat
# Processing Record 23 of Set 4 | jamestown
# Processing Record 24 of Set 4 | bethel
# Processing Record 25 of Set 4 | cockburn town
# Processing Record 26 of Set 4 | zhob
# Processing Record 27 of Set 4 | yinchuan
# Processing Record 28 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 4 | honningsvag
# Processing Record 30 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 4 | mnogovershinnyy
# Processing Record 32 of Set 4 | tubuala
# Processing Record 33 of Set 4 | pombas
# Processing Record 34 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 4 | hovd
# Processing Record 36 of Set 4 | vestmannaeyjar
# Processing Record 37 of Set 4 | chengde
# Processing Record 38 of Set 4 | ribeira grande
# Processing Record 39 of Set 4 | kodiak
# Processing Record 40 of Set 4 | lesosibirsk
# Processing Record 41 of Set 4 | edendale
# Processing Record 42 of Set 4 | tabou
# Processing Record 43 of Set 4 | kodinar
# Processing Record 44 of Set 4 | los llanos de aridane
# Processing Record 45 of Set 4 | coquimbo
# Processing Record 46 of Set 4 | trincomalee
# Processing Record 47 of Set 4 | batagay
# Processing Record 48 of Set 4 | itaituba
# Processing Record 49 of Set 4 | ostersund
# Processing Record 50 of Set 4 | marzuq
# Processing Record 1 of Set 5 | mount isa
# Processing Record 2 of Set 5 | cape town
# Processing Record 3 of Set 5 | bar harbor
# Processing Record 4 of Set 5 | shorewood
# Processing Record 5 of Set 5 | luderitz
# Processing Record 6 of Set 5 | santa cruz
# Processing Record 7 of Set 5 | bontang
# Processing Record 8 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 5 | krasnoselkup
# Processing Record 10 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 5 | potlogi
# Processing Record 12 of Set 5 | meulaboh
# Processing Record 13 of Set 5 | kahului
# Processing Record 14 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 15 of Set 5 | manama
# Processing Record 16 of Set 5 | rosh pinna
# Processing Record 17 of Set 5 | calca
# Processing Record 18 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 5 | chelmek
# Processing Record 20 of Set 5 | komsomolskiy
# Processing Record 21 of Set 5 | mahebourg
# Processing Record 22 of Set 5 | nakusp
# Processing Record 23 of Set 5 | neiafu
# Processing Record 24 of Set 5 | constitucion
# Processing Record 25 of Set 5 | kieta
# Processing Record 26 of Set 5 | mackay
# Processing Record 27 of Set 5 | cidreira
# Processing Record 28 of Set 5 | scarborough
# Processing Record 29 of Set 5 | iquitos
# Processing Record 30 of Set 5 | lompoc
# Processing Record 31 of Set 5 | neuquen
# Processing Record 32 of Set 5 | khani
# Processing Record 33 of Set 5 | djambala
# Processing Record 34 of Set 5 | bondoukou
# Processing Record 35 of Set 5 | kizema
# Processing Record 36 of Set 5 | lagoa
# Processing Record 37 of Set 5 | arman
# Processing Record 38 of Set 5 | saldanha
# Processing Record 39 of Set 5 | kavaratti
# Processing Record 40 of Set 5 | hithadhoo
# Processing Record 41 of Set 5 | abalak
# Processing Record 42 of Set 5 | baniyas
# Processing Record 43 of Set 5 | tobane
# Processing Record 44 of Set 5 | westport
# Processing Record 45 of Set 5 | baykit
# Processing Record 46 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 5 | berdigestyakh
# Processing Record 48 of Set 5 | poum
# Processing Record 49 of Set 5 | mayya
# Processing Record 50 of Set 5 | havoysund
# Processing Record 1 of Set 6 | whitecourt
# Processing Record 2 of Set 6 | notodden
# Processing Record 3 of Set 6 | ndende
# Processing Record 4 of Set 6 | ponnani
# Processing Record 5 of Set 6 | nome
# Processing Record 6 of Set 6 | casino
# Processing Record 7 of Set 6 | salalah
# Processing Record 8 of Set 6 | hirara
# Processing Record 9 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 10 of Set 6 | sabang
# Processing Record 11 of Set 6 | bengkulu
# Processing Record 12 of Set 6 | bambous virieux
# Processing Record 13 of Set 6 | shouguang
# Processing Record 14 of Set 6 | lons
# Processing Record 15 of Set 6 | namibe
# Processing Record 16 of Set 6 | ondarroa
# Processing Record 17 of Set 6 | fairbanks
# Processing Record 18 of Set 6 | novo aripuana
# Processing Record 19 of Set 6 | inhambane
# Processing Record 20 of Set 6 | tyukhtet
# Processing Record 21 of Set 6 | fort nelson
# Processing Record 22 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 6 | saint combs
# City not found. Skipping...
# Processing Record 24 of Set 6 | dori
# Processing Record 25 of Set 6 | am timan
# Processing Record 26 of Set 6 | gao
# Processing Record 27 of Set 6 | makakilo city
# Processing Record 28 of Set 6 | saint-pierre
# Processing Record 29 of Set 6 | broome
# Processing Record 30 of Set 6 | waipawa
# Processing Record 31 of Set 6 | celestun
# Processing Record 32 of Set 6 | valdivia
# Processing Record 33 of Set 6 | aasiaat
# Processing Record 34 of Set 6 | pemba
# Processing Record 35 of Set 6 | east london
# Processing Record 36 of Set 6 | sechura
# Processing Record 37 of Set 6 | new norfolk
# Processing Record 38 of Set 6 | tanete
# Processing Record 39 of Set 6 | royan
# Processing Record 40 of Set 6 | cabo san lucas
# Processing Record 41 of Set 6 | victoria point
# Processing Record 42 of Set 6 | shu
# Processing Record 43 of Set 6 | necochea
# Processing Record 44 of Set 6 | pevek
# Processing Record 45 of Set 6 | kiruna
# Processing Record 46 of Set 6 | bambanglipuro
# Processing Record 47 of Set 6 | steamboat springs
# Processing Record 48 of Set 6 | carmo do rio claro
# Processing Record 49 of Set 6 | pacific grove
# Processing Record 50 of Set 6 | isangel
# Processing Record 1 of Set 7 | shimoda
# Processing Record 2 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 3 of Set 7 | hambantota
# Processing Record 4 of Set 7 | cabinda
# Processing Record 5 of Set 7 | walvis bay
# Processing Record 6 of Set 7 | boguchany
# Processing Record 7 of Set 7 | khatanga
# Processing Record 8 of Set 7 | rawson
# Processing Record 9 of Set 7 | tanout
# Processing Record 10 of Set 7 | fayaoue
# Processing Record 11 of Set 7 | mayumba
# Processing Record 12 of Set 7 | grand gaube
# Processing Record 13 of Set 7 | husavik
# Processing Record 14 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 15 of Set 7 | bethanien
# Processing Record 16 of Set 7 | san patricio
# Processing Record 17 of Set 7 | morrope
# Processing Record 18 of Set 7 | benghazi
# Processing Record 19 of Set 7 | payo
# Processing Record 20 of Set 7 | yevlax
# Processing Record 21 of Set 7 | sao joao da barra
# Processing Record 22 of Set 7 | luau
# Processing Record 23 of Set 7 | kamaishi
# Processing Record 24 of Set 7 | estepona
# Processing Record 25 of Set 7 | xuchang
# Processing Record 26 of Set 7 | redford
# Processing Record 27 of Set 7 | marystown
# Processing Record 28 of Set 7 | angol
# Processing Record 29 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 30 of Set 7 | hinton
# Processing Record 31 of Set 7 | tocache
# Processing Record 32 of Set 7 | boatlaname
# City not found. Skipping...
# Processing Record 33 of Set 7 | namatanai
# Processing Record 34 of Set 7 | homer
# Processing Record 35 of Set 7 | tungor
# Processing Record 36 of Set 7 | zonguldak
# Processing Record 37 of Set 7 | loiza
# Processing Record 38 of Set 7 | caninde
# Processing Record 39 of Set 7 | konstantinovskaya
# Processing Record 40 of Set 7 | tuktoyaktuk
# Processing Record 41 of Set 7 | yaring
# Processing Record 42 of Set 7 | turkeve
# Processing Record 43 of Set 7 | tiruvottiyur
# City not found. Skipping...
# Processing Record 44 of Set 7 | marrakesh
# Processing Record 45 of Set 7 | jiwani
# Processing Record 46 of Set 7 | alofi
# Processing Record 47 of Set 7 | kem
# Processing Record 48 of Set 7 | biak
# Processing Record 49 of Set 7 | araouane
# Processing Record 50 of Set 7 | naifaru
# Processing Record 1 of Set 8 | calvinia
# Processing Record 2 of Set 8 | rundu
# Processing Record 3 of Set 8 | sao jose da coroa grande
# Processing Record 4 of Set 8 | kobryn
# Processing Record 5 of Set 8 | kvareli
# Processing Record 6 of Set 8 | molango
# Processing Record 7 of Set 8 | key largo
# Processing Record 8 of Set 8 | montrose
# Processing Record 9 of Set 8 | te anau
# Processing Record 10 of Set 8 | ostrovnoy
# Processing Record 11 of Set 8 | banda aceh
# Processing Record 12 of Set 8 | upington
# Processing Record 13 of Set 8 | suifenhe
# Processing Record 14 of Set 8 | celendin
# Processing Record 15 of Set 8 | lyaskelya
# Processing Record 16 of Set 8 | veraval
# Processing Record 17 of Set 8 | amarkantak
# Processing Record 18 of Set 8 | touros
# Processing Record 19 of Set 8 | tyrma
# Processing Record 20 of Set 8 | tomelloso
# Processing Record 21 of Set 8 | nortelandia
# Processing Record 22 of Set 8 | gweru
# Processing Record 23 of Set 8 | teya
# Processing Record 24 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 25 of Set 8 | ilulissat
# Processing Record 26 of Set 8 | amurzet
# Processing Record 27 of Set 8 | gilbues
# Processing Record 28 of Set 8 | urumqi
# Processing Record 29 of Set 8 | narrabri
# Processing Record 30 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 8 | sindgi
# Processing Record 33 of Set 8 | sompeta
# Processing Record 34 of Set 8 | belmonte
# Processing Record 35 of Set 8 | kijang
# Processing Record 36 of Set 8 | kingisepp
# Processing Record 37 of Set 8 | kuala terengganu
# Processing Record 38 of Set 8 | kutum
# Processing Record 39 of Set 8 | tessalit
# Processing Record 40 of Set 8 | teahupoo
# Processing Record 41 of Set 8 | hvammstangi
# City not found. Skipping...
# Processing Record 42 of Set 8 | omboue
# Processing Record 43 of Set 8 | oxelosund
# Processing Record 44 of Set 8 | bindura
# Processing Record 45 of Set 8 | mari
# Processing Record 46 of Set 8 | marawi
# Processing Record 47 of Set 8 | flinders
# Processing Record 48 of Set 8 | capreol
# Processing Record 49 of Set 8 | havelock
# Processing Record 50 of Set 8 | pisco
# Processing Record 1 of Set 9 | sitka
# Processing Record 2 of Set 9 | lucea
# Processing Record 3 of Set 9 | mawana
# Processing Record 4 of Set 9 | pratapgarh
# Processing Record 5 of Set 9 | ajaccio
# Processing Record 6 of Set 9 | changli
# Processing Record 7 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 9 | moss vale
# Processing Record 9 of Set 9 | chara
# Processing Record 10 of Set 9 | linxia
# Processing Record 11 of Set 9 | batabano
# Processing Record 12 of Set 9 | buraydah
# Processing Record 13 of Set 9 | ara
# Processing Record 14 of Set 9 | praia da vitoria
# Processing Record 15 of Set 9 | srednekolymsk
# Processing Record 16 of Set 9 | melfi
# Processing Record 17 of Set 9 | dunedin
# Processing Record 18 of Set 9 | amahai
# Processing Record 19 of Set 9 | evensk
# Processing Record 20 of Set 9 | tambopata
# Processing Record 21 of Set 9 | vredendal
# Processing Record 22 of Set 9 | yumen
# Processing Record 23 of Set 9 | port-cartier
# Processing Record 24 of Set 9 | valentin gomez farias
# Processing Record 25 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 26 of Set 9 | plettenberg bay
# Processing Record 27 of Set 9 | taksimo
# Processing Record 28 of Set 9 | kaohsiung
# Processing Record 29 of Set 9 | thermon
# City not found. Skipping...
# Processing Record 30 of Set 9 | svetlaya
# Processing Record 31 of Set 9 | iqaluit
# Processing Record 32 of Set 9 | altay
# Processing Record 33 of Set 9 | holland
# Processing Record 34 of Set 9 | tautira
# Processing Record 35 of Set 9 | mount gambier
# Processing Record 36 of Set 9 | verkhnyaya sysert
# Processing Record 37 of Set 9 | tezu
# Processing Record 38 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 9 | bredy
# Processing Record 40 of Set 9 | traralgon
# Processing Record 41 of Set 9 | port shepstone
# Processing Record 42 of Set 9 | abu samrah
# Processing Record 43 of Set 9 | udachnyy
# Processing Record 44 of Set 9 | norfolk
# Processing Record 45 of Set 9 | lensk
# Processing Record 46 of Set 9 | beipiao
# Processing Record 47 of Set 9 | uyemskiy
# Processing Record 48 of Set 9 | moose factory
# Processing Record 49 of Set 9 | kaeo
# Processing Record 50 of Set 9 | bubaque
# Processing Record 1 of Set 10 | norman wells
# Processing Record 2 of Set 10 | adrar
# Processing Record 3 of Set 10 | roald
# Processing Record 4 of Set 10 | miri
# Processing Record 5 of Set 10 | hami
# Processing Record 6 of Set 10 | bandarbeyla
# Processing Record 7 of Set 10 | solnechnyy
# Processing Record 8 of Set 10 | rio grande
# Processing Record 9 of Set 10 | black river
# Processing Record 10 of Set 10 | buin
# Processing Record 11 of Set 10 | sayansk
# Processing Record 12 of Set 10 | osoyoos
# Processing Record 13 of Set 10 | gornopravdinsk
# Processing Record 14 of Set 10 | nizhniy kuranakh
# Processing Record 15 of Set 10 | kulu
# Processing Record 16 of Set 10 | sarkand
# Processing Record 17 of Set 10 | gazanjyk
# Processing Record 18 of Set 10 | nelson bay
# Processing Record 19 of Set 10 | andenes
# Processing Record 20 of Set 10 | beloha
# Processing Record 21 of Set 10 | leh
# Processing Record 22 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 10 | oak harbor
# Processing Record 24 of Set 10 | vao
# Processing Record 25 of Set 10 | opelika
# Processing Record 26 of Set 10 | vilhena
# Processing Record 27 of Set 10 | manadhoo
# Processing Record 28 of Set 10 | bikin
# Processing Record 29 of Set 10 | kaitangata
# Processing Record 30 of Set 10 | kenai
# Processing Record 31 of Set 10 | nsanje
# Processing Record 32 of Set 10 | katangli
# Processing Record 33 of Set 10 | vostok
# Processing Record 34 of Set 10 | labuhan
# Processing Record 35 of Set 10 | jinchang
# Processing Record 36 of Set 10 | sorrento
# Processing Record 37 of Set 10 | oga
# Processing Record 38 of Set 10 | half moon bay
# Processing Record 39 of Set 10 | san quintin
# Processing Record 40 of Set 10 | euclid
# Processing Record 41 of Set 10 | sarany
# Processing Record 42 of Set 10 | yulara
# Processing Record 43 of Set 10 | chicama
# Processing Record 44 of Set 10 | zwedru
# Processing Record 45 of Set 10 | ferme-neuve
# Processing Record 46 of Set 10 | cedeno
# Processing Record 47 of Set 10 | mathathane
# Processing Record 48 of Set 10 | coffs harbour
# Processing Record 49 of Set 10 | wajid
# Processing Record 50 of Set 10 | japura
# Processing Record 1 of Set 11 | sorong
# Processing Record 2 of Set 11 | cap malheureux
# Processing Record 3 of Set 11 | chapais
# Processing Record 4 of Set 11 | kartuzy
# Processing Record 5 of Set 11 | fortuna
# Processing Record 6 of Set 11 | ruiru
# Processing Record 7 of Set 11 | wenling
# Processing Record 8 of Set 11 | matay
# Processing Record 9 of Set 11 | gambiran
# Processing Record 10 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 11 | mzimba
# Processing Record 12 of Set 11 | canita
# Processing Record 13 of Set 11 | tevaitoa
# Processing Record 14 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 11 | stromness
# Processing Record 16 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 17 of Set 11 | nieuw nickerie
# Processing Record 18 of Set 11 | nemuro
# Processing Record 19 of Set 11 | bourail
# Processing Record 20 of Set 11 | saquena
# Processing Record 21 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 22 of Set 11 | torata
# Processing Record 23 of Set 11 | agutaya
# Processing Record 24 of Set 11 | mecca
# Processing Record 25 of Set 11 | puteyets
# Processing Record 26 of Set 11 | rabo de peixe
# Processing Record 27 of Set 11 | ures
# Processing Record 28 of Set 11 | lewiston
# Processing Record 29 of Set 11 | rochegda
# Processing Record 30 of Set 11 | berlevag
# Processing Record 31 of Set 11 | pochutla
# Processing Record 32 of Set 11 | washougal
# Processing Record 33 of Set 11 | katsuura
# Processing Record 34 of Set 11 | evans
# Processing Record 35 of Set 11 | kundiawa
# Processing Record 36 of Set 11 | bilibino
# Processing Record 37 of Set 11 | alvaraes
# Processing Record 38 of Set 11 | dahod
# Processing Record 39 of Set 11 | pauini
# Processing Record 40 of Set 11 | la union
# Processing Record 41 of Set 11 | anadyr
# Processing Record 42 of Set 11 | chabahar
# Processing Record 43 of Set 11 | durango
# Processing Record 44 of Set 11 | port-gentil
# Processing Record 45 of Set 11 | skegness
# Processing Record 46 of Set 11 | bangangte
# Processing Record 47 of Set 11 | dogondoutchi
# Processing Record 48 of Set 11 | gat
# Processing Record 49 of Set 11 | hofn
# Processing Record 50 of Set 11 | madingou
# Processing Record 1 of Set 12 | thuro
# City not found. Skipping...
# Processing Record 2 of Set 12 | laguna
# Processing Record 3 of Set 12 | ahipara
# Processing Record 4 of Set 12 | yerbogachen
# Processing Record 5 of Set 12 | beringovskiy
# Processing Record 6 of Set 12 | naze
# Processing Record 7 of Set 12 | zhanaozen
# Processing Record 8 of Set 12 | benjamin aceval
# Processing Record 9 of Set 12 | osorno
# Processing Record 10 of Set 12 | ciudad guayana
# Processing Record 11 of Set 12 | manakara
# Processing Record 12 of Set 12 | sungaipenuh
# Processing Record 13 of Set 12 | coahuayana
# Processing Record 14 of Set 12 | fukue
# Processing Record 15 of Set 12 | riyadh
# Processing Record 16 of Set 12 | lakatoro
# Processing Record 17 of Set 12 | lano
# Processing Record 18 of Set 12 | ibra
# Processing Record 19 of Set 12 | mana
# Processing Record 20 of Set 12 | almaznyy
# Processing Record 21 of Set 12 | boyuibe
# Processing Record 22 of Set 12 | hay river
# Processing Record 23 of Set 12 | san rafael
# Processing Record 24 of Set 12 | talcahuano
# Processing Record 25 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 12 | asau
# Processing Record 27 of Set 12 | wanaka
# Processing Record 28 of Set 12 | morondava
# Processing Record 29 of Set 12 | canar
# Processing Record 30 of Set 12 | kalmunai
# Processing Record 31 of Set 12 | anchorage
# Processing Record 32 of Set 12 | port hardy
# Processing Record 33 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 12 | college
# Processing Record 35 of Set 12 | aklavik
# Processing Record 36 of Set 12 | dali
# Processing Record 37 of Set 12 | skelleftea
# Processing Record 38 of Set 12 | beira
# Processing Record 39 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 12 | abapo
# Processing Record 41 of Set 12 | maua
# Processing Record 42 of Set 12 | mason city
# Processing Record 43 of Set 12 | oudtshoorn
# Processing Record 44 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 45 of Set 12 | belfast
# Processing Record 46 of Set 12 | kisangani
# Processing Record 47 of Set 12 | dvinskoy
# Processing Record 48 of Set 12 | dodge city
# Processing Record 49 of Set 12 | koumac
# Processing Record 50 of Set 12 | caconda
# Processing Record 1 of Set 13 | panacan
# Processing Record 2 of Set 13 | padang
# Processing Record 3 of Set 13 | kruisfontein
# Processing Record 4 of Set 13 | sorata
# Processing Record 5 of Set 13 | pankrushikha
# Processing Record 6 of Set 13 | ati
# Processing Record 7 of Set 13 | tilichiki
# Processing Record 8 of Set 13 | aquiraz
# Processing Record 9 of Set 13 | cliza
# Processing Record 10 of Set 13 | mumford
# Processing Record 11 of Set 13 | sao filipe
# Processing Record 12 of Set 13 | mollendo
# Processing Record 13 of Set 13 | ulaangom
# Processing Record 14 of Set 13 | shingu
# Processing Record 15 of Set 13 | sedalia
# Processing Record 16 of Set 13 | marsh harbour
# Processing Record 17 of Set 13 | yantal
# Processing Record 18 of Set 13 | hirtshals
# Processing Record 19 of Set 13 | noumea
# Processing Record 20 of Set 13 | cam pha
# City not found. Skipping...
# Processing Record 21 of Set 13 | kochubey
# Processing Record 22 of Set 13 | sept-iles
# Processing Record 23 of Set 13 | kastrakion
# Processing Record 24 of Set 13 | sangar
# Processing Record 25 of Set 13 | reshetylivka
# Processing Record 26 of Set 13 | stornoway
# Processing Record 27 of Set 13 | barra do corda
# Processing Record 28 of Set 13 | mindelo
# Processing Record 29 of Set 13 | villa carlos paz
# Processing Record 30 of Set 13 | pak phanang
# Processing Record 31 of Set 13 | naryan-mar
# Processing Record 32 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 33 of Set 13 | bonfim
# Processing Record 34 of Set 13 | lahaina
# Processing Record 35 of Set 13 | karpogory
# Processing Record 36 of Set 13 | orlik
# Processing Record 37 of Set 13 | saint-augustin
# Processing Record 38 of Set 13 | chifeng
# Processing Record 39 of Set 13 | wewak
# Processing Record 40 of Set 13 | lynden
# Processing Record 41 of Set 13 | bratsk
# Processing Record 42 of Set 13 | cururupu
# Processing Record 43 of Set 13 | seoul
# Processing Record 44 of Set 13 | kuching
# Processing Record 45 of Set 13 | lavrentiya
# Processing Record 46 of Set 13 | bima
# Processing Record 47 of Set 13 | denpasar
# Processing Record 48 of Set 13 | hualmay
# Processing Record 49 of Set 13 | waingapu
# Processing Record 50 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 14 | vanimo
# Processing Record 2 of Set 14 | khor
# Processing Record 3 of Set 14 | kiama
# Processing Record 4 of Set 14 | medina del campo
# Processing Record 5 of Set 14 | robat karim
# Processing Record 6 of Set 14 | karratha
# Processing Record 7 of Set 14 | serov
# Processing Record 8 of Set 14 | nabire
# Processing Record 9 of Set 14 | kismayo
# Processing Record 10 of Set 14 | north platte
# Processing Record 11 of Set 14 | santa
# Processing Record 12 of Set 14 | monroe
# Processing Record 13 of Set 14 | juelsminde
# Processing Record 14 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 15 of Set 14 | caraballeda
# Processing Record 16 of Set 14 | sisimiut
# Processing Record 17 of Set 14 | zheleznodorozhnyy
# Processing Record 18 of Set 14 | beyneu
# Processing Record 19 of Set 14 | holme
# Processing Record 20 of Set 14 | turukhansk
# Processing Record 21 of Set 14 | parkes
# Processing Record 22 of Set 14 | oron
# Processing Record 23 of Set 14 | lebu
# Processing Record 24 of Set 14 | saint-leu
# Processing Record 25 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 26 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 27 of Set 14 | kysyl-syr
# Processing Record 28 of Set 14 | lucapa
# Processing Record 29 of Set 14 | suntar
# Processing Record 30 of Set 14 | rudbar
# Processing Record 31 of Set 14 | kabanjahe
# Processing Record 32 of Set 14 | vestmanna
# Processing Record 33 of Set 14 | newport
# Processing Record 34 of Set 14 | looc
# Processing Record 35 of Set 14 | darab
# Processing Record 36 of Set 14 | miraflores
# Processing Record 37 of Set 14 | aakirkeby
# City not found. Skipping...
# Processing Record 38 of Set 14 | canavieiras
# Processing Record 39 of Set 14 | majene
# Processing Record 40 of Set 14 | sakakah
# Processing Record 41 of Set 14 | leningradskiy
# Processing Record 42 of Set 14 | muroto
# Processing Record 43 of Set 14 | uthal
# Processing Record 44 of Set 14 | carmen
# Processing Record 45 of Set 14 | yuzhno-sukhokumsk
# Processing Record 46 of Set 14 | flin flon
# Processing Record 47 of Set 14 | katsiveli
# City not found. Skipping...
# Processing Record 48 of Set 14 | jiuquan
# Processing Record 49 of Set 14 | moorhead
# Processing Record 50 of Set 14 | puerto montt
# Processing Record 1 of Set 15 | pedra azul
# Processing Record 2 of Set 15 | plerin
# Processing Record 3 of Set 15 | aybak
# City not found. Skipping...
# Processing Record 4 of Set 15 | wadi musa
# Processing Record 5 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 6 of Set 15 | ibanda
# Processing Record 7 of Set 15 | sola
# Processing Record 8 of Set 15 | nhulunbuy
# Processing Record 9 of Set 15 | ntcheu
# Processing Record 10 of Set 15 | faya
# Processing Record 11 of Set 15 | basoko
# Processing Record 12 of Set 15 | kawalu
# Processing Record 13 of Set 15 | cadolzburg
# Processing Record 14 of Set 15 | lorengau
# Processing Record 15 of Set 15 | bongandanga
# Processing Record 16 of Set 15 | polovinnoye
# Processing Record 17 of Set 15 | doha
# Processing Record 18 of Set 15 | burla
# Processing Record 19 of Set 15 | rio tercero
# Processing Record 20 of Set 15 | saint leonard
# Processing Record 21 of Set 15 | hov
# Processing Record 22 of Set 15 | mantua
# Processing Record 23 of Set 15 | sarakhs
# Processing Record 24 of Set 15 | argelia
# Processing Record 25 of Set 15 | boende
# Processing Record 26 of Set 15 | borovoy
# Processing Record 27 of Set 15 | manaure
# Processing Record 28 of Set 15 | formosa do rio preto
# Processing Record 29 of Set 15 | dingle
# Processing Record 30 of Set 15 | port keats
# Processing Record 31 of Set 15 | manthani
# Processing Record 32 of Set 15 | tabuk
# Processing Record 33 of Set 15 | hobyo
# Processing Record 34 of Set 15 | uyovu
# Processing Record 35 of Set 15 | erbach
# Processing Record 36 of Set 15 | lakhdenpokhya
# Processing Record 37 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 38 of Set 15 | alexandria
# Processing Record 39 of Set 15 | chitungwiza
# Processing Record 40 of Set 15 | kamenka
# Processing Record 41 of Set 15 | north bend
# Processing Record 42 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 43 of Set 15 | puerto penasco
# Processing Record 44 of Set 15 | port macquarie
# Processing Record 45 of Set 15 | leirvik
# Processing Record 46 of Set 15 | taungdwingyi
# Processing Record 47 of Set 15 | bianzhuang
# Processing Record 48 of Set 15 | puerto ayacucho
# Processing Record 49 of Set 15 | juneau
# Processing Record 50 of Set 15 | jiquilisco
# Processing Record 1 of Set 16 | ortona
# Processing Record 2 of Set 16 | lahan
# Processing Record 3 of Set 16 | agnibilekrou
# Processing Record 4 of Set 16 | cruz das almas
# Processing Record 5 of Set 16 | salta
# Processing Record 6 of Set 16 | skagastrond
# City not found. Skipping...
# Processing Record 7 of Set 16 | hammond
# Processing Record 8 of Set 16 | virginia beach
# Processing Record 9 of Set 16 | svetlyy
# Processing Record 10 of Set 16 | deputatskiy
# Processing Record 11 of Set 16 | bati
# Processing Record 12 of Set 16 | najran
# Processing Record 13 of Set 16 | la palma
# Processing Record 14 of Set 16 | aranos
# Processing Record 15 of Set 16 | madimba
# Processing Record 16 of Set 16 | redmond
# Processing Record 17 of Set 16 | ambulu
# Processing Record 18 of Set 16 | vallenar
# Processing Record 19 of Set 16 | saint anthony

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.sample(5)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 701   Wadi Musa  30.3222   35.4793     70.83        59           0
# 180     Gigmoto  13.7796  124.3900     80.08        84          97
# 89    Upernavik  72.7868  -56.1549     42.10        81         100
# 277      Baykit  61.6700   96.3700     44.83        88          30
# 512  Mathathane -22.2687   28.7495     66.78        41           0
#
#      Wind Speed Current Conditions
# 701        3.71          clear sky
# 180        1.68    overcast clouds
# 89        10.60    overcast clouds
# 277        3.65   scattered clouds
# 512        8.01          clear sky

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
